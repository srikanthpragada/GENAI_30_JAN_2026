# %% [markdown]
# ## Notebook Demo

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-02-17 20:50:26.387142

# %% [markdown]
# ### Use methods of date

# %%
name = input("Enter your name :")

# %%
print(name)
# Out:
# Srikanth

# %%
if name == 'end':
        print('The End')
else:
  print("Name = ", name)
# Out:
# Name =  Srikanth

# %%
print('Over')
# Out:
# Over
